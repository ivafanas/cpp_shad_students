# %% [markdown]
# **Вопросы для повторения**:
#
# 1. Что имеется ввиду под compiletime и runtime контекстами выполнения?
# 2. Какие функции:
#   * можно выполнять только в runtime?
#   * можно выполнять и в compiletime и в runtime?
#   * можно выполнять только в compiletime?
# 3. Какой здесь контекст выполнения у функции `f`?
#
# ```c++
# // определим саму f
# constexpr int f(int) { /*...*/ }
#
# // 1
# int g()
# {
#     constexpr int res = f(3);
#     return res;
# }
#
# // 2
# int main(int argc, char **argv)
# {
#     return f(argc);
# }
#
# // 3
# int main(int argc, char **argv)
# {
#     return f(3);
# }
#
# // 4
# constexpr int g(int x)
# {
#     return f(x);
# }
# ```
#
# 4. Что с этим кодом?
#
# ```c++
# constexpr int factorial(int n)
# {
#     return n <= 1 ? 1 : n * factorial(n - 1);
# }
#
# constexpr int x = factorial(50);
# ```
#
# 5. Как тестировать constexpr-функции?
# 6. Зачем придумали constinit?
# 7. Какой конструктор здесь будет вызван?
#
# ```c++
# std::string&&       get_name_1();
# const std::string   get_name_2();
# std::string         get_name_3();
#
# std::string x = get_name_1();  // ???
# std::string x = get_name_2();  // ???
# std::string x = get_name_3();  // ???
# ```
