# %% [markdown]
# __Вопросы для повторения__:
#
# * в чём здесь проблема?
#
# ```c++
# std::vector<int> v;
# for (int i = 0; i < 1024; ++i)
#     if (i % 2 == 0)
#         v.push_back(i);
# ```
#
# <details>
# <summary>Подсказка</summary>
# <p>
#
# `reserve` + лишний `%`
#
# </p>
# </details>
#
# * здесь?
#
# ```c++
# std::vector<std::string> team = ...;
# for (auto it = team.begin(); it <= team.end(); ++it)
#     std::cout << *it << std::endl;
# ```
#
# <details>
# <summary>Подсказка</summary>
# <p>
#
# разыменование end
#
# </p>
# </details>
#
# * сколько здесь аллокаций? какие?
#
# ```c++
# std::deque<std::string> team;
# for (int i = 0; i < N; ++i)
#     team.emplace_back("imperial storm trooper");
# ```
#
# <details>
# <summary>Подсказка</summary>
# <p>
#
# `N` аллокаций на конструирование строк, `N / размер блока` аллокаций под блоки дека + аллокации на таблицу блоков в деке.
#
# </p>
# </details>
#
# * что будет выведено здесь?
#
# ```c++
# std::vector<int> v = {10, 20, 30, 40, 50};
#
# auto it1 = v.begin();
# auto it2 = std::next(it1);
# auto it3 = std::next(it2);
# auto it4 = std::next(it3);
#
# v.insert(it3, 25);
#
# std::cout << *it1 << std::endl;
# std::cout << *it2 << std::endl;
# std::cout << *it3 << std::endl;
# std::cout << *it4 << std::endl;
# ```
#
# <details>
# <summary>Подсказка</summary>
# <p>
#
# Все итераторы после вставки инвалидированы, разыменование инвалидированых итераторов - ub.
#
# </p>
# </details>

# %% [markdown]
# * Выберите тип контейнера для хранения данных под задачу:
#   * В университете N студентов. Их id пронумерованы от 1 до N. Нужно по id студента возвращать его ФИО.
#   * В университете N студентов. Их id - целые числа - сгенерированы случайным образом. Нужно по id студента возвращать его ФИО.
#   * В ЦПУ Эльбрус 6 арифметико-логических устройств. Нужно по номеру устройства возвращать информацию о нём (например, список кодов инструкций, которые могут выполняться на этом устройстве)
#   * У человека <= 32 зубов. Нужно хранить информацию, есть у человека i-ый зуб или нет.
#   * У человека <= 40 зубов. Нужно хранить информацию, есть у человека зуб или нет.
